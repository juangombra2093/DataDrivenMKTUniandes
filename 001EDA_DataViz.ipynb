# %% [markdown]
# # **Exploración inicial de datos** 👓

# %%
#cargar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Vincular Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define la ruta de tu archivo de Excel
file_path = '/content/drive/MyDrive/Colab Notebooks/Universidad de los Andes/ifood_df.xlsx'

# Lee el archivo de Excel y carga los datos en un DataFrame de pandas
df = pd.read_excel(file_path)

# Muestra el DataFrame
df.head()
# Out:
#    Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0   58138        0         0       58       635         88              546
# 1   46344        1         1       38        11          1                6
# 2   71613        0         0       26       426         49              127
# 3   26646        1         0       26        11          4               20
# 4   58293        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.dtypes
# Out:
# Income                  int64
# Kidhome                 int64
# Teenhome                int64
# Recency                 int64
# MntWines                int64
# MntFruits               int64
# MntMeatProducts         int64
# MntFishProducts         int64
# MntSweetProducts        int64
# MntGoldProds            int64
# NumDealsPurchases       int64
# NumWebPurchases         int64
# NumCatalogPurchases     int64
# NumStorePurchases       int64
# NumWebVisitsMonth       int64
# AcceptedCmp3            int64
# AcceptedCmp4            int64
# AcceptedCmp5            int64
# AcceptedCmp1            int64
# AcceptedCmp2            int64
# Complain                int64
# Z_CostContact           int64
# Z_Revenue               int64
# Response                int64
# Age                     int64
# Customer_Days           int64
# marital_Divorced        int64
# marital_Married         int64
# marital_Single          int64
# marital_Together        int64
# marital_Widow           int64
# ...

# %%
df.describe(include='all').T
# Out:
#                        count          mean           std     min      25%  \
# Income                2205.0  51622.094785  20713.063826  1730.0  35196.0
# Kidhome               2205.0      0.442177      0.537132     0.0      0.0
# Teenhome              2205.0      0.506576      0.544380     0.0      0.0
# Recency               2205.0     49.009070     28.932111     0.0     24.0
# MntWines              2205.0    306.164626    337.493839     0.0     24.0
# MntFruits             2205.0     26.403175     39.784484     0.0      2.0
# MntMeatProducts       2205.0    165.312018    217.784507     0.0     16.0
# MntFishProducts       2205.0     37.756463     54.824635     0.0      3.0
# MntSweetProducts      2205.0     27.128345     41.130468     0.0      1.0
# MntGoldProds          2205.0     44.057143     51.736211     0.0      9.0
# NumDealsPurchases     2205.0      2.318367      1.886107     0.0      1.0
# NumWebPurchases       2205.0      4.100680      2.737424     0.0      2.0
# ...

# %% [markdown]
# # **Analisis Grafico** 📊

# %%
#Boxplot
plt.figure(figsize=(8, 6))  # Ajusta el tamaño del gráfico si es necesario
sns.boxplot(data=df, x='Income')
plt.title('Boxplot de Income')
plt.xlabel('Income')
plt.show()

# %%
#Diagrama de densidad
plt.figure(figsize=(8, 6))  # Ajusta el tamaño del gráfico si es necesario
sns.kdeplot(data=df, x='Income', fill=True, color='blue', common_norm=False)
sns.histplot(data=df, x='Income', kde=True, color='blue', bins=30)
plt.title('Diagrama de Densidad de Income')
plt.xlabel('Income')
plt.show()

# %%
# Crear el gráfico de barras
df['Kidhome'].value_counts().plot(kind='bar')

# Agregar título y etiquetas
plt.title('Distribución de Kidhome')
plt.xlabel('Número de niños en el hogar')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
# Crear el diagrama de dispersión
plt.figure(figsize=(8, 6))  # Ajusta el tamaño del gráfico si es necesario
sns.scatterplot(data=df, x='MntTotal', y='Income', color='blue', alpha=0.5)  # Diagrama de dispersión
sns.regplot(data=df, x='MntTotal', y='Income', color='red', scatter=False)  # Línea de tendencia
plt.title('Diagrama de Dispersión entre MntTotal e Income con Línea de Tendencia')
plt.xlabel('MntTotal')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# # **Matriz de Correlacion**

# %%
# Lista con los nombres de las columnas numéricas que te interesan
columnas_a_incluir = ['Income','MntMeatProducts','MntWines','MntFruits',
                      'MntFishProducts','MntSweetProducts','MntGoldProds']

# Filtrar el DataFrame utilizando la lista
df_numeric = df[columnas_a_incluir]

# %%
corr_matrix = df_numeric.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %%
#Borrar Variables que no aportan al analisis
# Crear una lista con los nombres de las columnas a eliminar
columnas_a_eliminar = ['Z_CostContact', 'Z_Revenue']

# Eliminar las columnas del DataFrame
df = df.drop(columnas_a_eliminar, axis=1)

# %%
df.head()
# Out:
#    Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0   58138        0         0       58       635         88              546
# 1   46344        1         1       38        11          1                6
# 2   71613        0         0       26       426         49              127
# 3   26646        1         0       26        11          4               20
# 4   58293        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...
